# %%
from reconstruction import MultiTreeReconstruction
import numpy as np
import json
import networkx as nx
import matplotlib.pyplot as plt

# %%
# class MultiTreeReconstruction:
#     """
#     Reconstruct multiple independent vascular trees from a single point cloud
#     """
#     def __init__(self, skeleton_points, n_trees=3, gamma=3.0, mu=3.6e-3, 
#                  Q_perf=0.125, P_out=60, P_in=100):
#         """
#         Parameters:
#         -----------
#         skeleton_points : np.array, shape (N, 3)
#             3D coordinates of skeleton points
#         n_trees : int
#             Expected number of separate trees to extract
#         gamma, mu, Q_perf, P_out, P_in : float
#             CCO physiological parameters (same as VascularTreeReconstruction)
#         """
#         self.original_points = np.array(skeleton_points)
#         self.n_trees = n_trees
#         self.gamma = gamma
#         self.mu = mu
#         self.Q_perf = Q_perf
#         self.P_out = P_out
#         self.P_in = P_in
        
#         self.trees = []  # List of reconstructed trees
#         self.remaining_points = self.original_points.copy()
#         self.point_to_tree_mapping = {}  # Maps original point index to tree index
        
#     def reconstruct_multiple_trees(self, k_neighbors_initial=5, k_neighbors_optimization=10,
#                                    min_tree_size=50, max_iterations=10):
#         """
#         Extract multiple trees iteratively
        
#         Parameters:
#         -----------
#         k_neighbors_initial : int
#             Low k for initial sparse connectivity (helps separate trees)
#         k_neighbors_optimization : int
#             Higher k for optimizing individual trees
#         min_tree_size : int
#             Minimum number of points required for a valid tree
#         max_iterations : int
#             Maximum number of trees to extract
        
#         Returns:
#         --------
#         trees : list of dict
#             List of tree structures, each containing:
#             - 'tree': networkx.DiGraph
#             - 'root': int (root node in original point indexing)
#             - 'radii': dict
#             - 'metrics': dict
#             - 'points': np.array (points for this tree)
#             - 'point_indices': list (indices in original point cloud)
#         """
#         print(f"Starting multi-tree reconstruction from {len(self.original_points)} points")
#         print(f"Target: {self.n_trees} trees\n")
        
#         iteration = 0
        
#         while len(self.remaining_points) >= min_tree_size and iteration < max_iterations:
#             iteration += 1
#             print(f"{'='*60}")
#             print(f"ITERATION {iteration}: {len(self.remaining_points)} points remaining")
#             print(f"{'='*60}\n")
            
#             # Extract one tree from remaining points
#             tree_data = self._extract_single_tree(
#                 k_neighbors_initial=k_neighbors_initial,
#                 k_neighbors_optimization=k_neighbors_optimization,
#                 min_tree_size=min_tree_size
#             )
            
#             if tree_data is None:
#                 print("No more valid trees found. Stopping.")
#                 break
            
#             self.trees.append(tree_data)
            
#             # Remove points belonging to this tree
#             self._remove_tree_points(tree_data)
            
#             print(f"\n✓ Tree {iteration} extracted: {len(tree_data['point_indices'])} points")
#             print(f"  Root at: {tree_data['points'][tree_data['root']]}")
#             print(f"  Terminals: {len([n for n in tree_data['tree'].nodes() if tree_data['tree'].out_degree(n) == 0])}")
#             print(f"  Total volume: {tree_data['metrics']['total_volume']:.2f} mm³")
#             print(f"  Remaining points: {len(self.remaining_points)}\n")
            
#             # Stop if we've extracted enough trees
#             if len(self.trees) >= self.n_trees:
#                 print(f"Extracted target number of trees ({self.n_trees}). Stopping.")
#                 break
        
#         print(f"\n{'='*60}")
#         print(f"FINAL RESULT: {len(self.trees)} trees extracted")
#         print(f"{'='*60}")
        
#         for i, tree_data in enumerate(self.trees):
#             print(f"Tree {i+1}: {len(tree_data['point_indices'])} points, "
#                   f"volume={tree_data['metrics']['total_volume']:.2f} mm³")
        
#         if len(self.remaining_points) > 0:
#             print(f"\nWarning: {len(self.remaining_points)} points not assigned to any tree")
        
#         return self.trees
    
#     def _extract_single_tree(self, k_neighbors_initial, k_neighbors_optimization, min_tree_size):
#         """
#         Extract one tree from remaining points using sparse connectivity
#         """
#         if len(self.remaining_points) < min_tree_size:
#             return None
        
#         # Step 1: Build sparse graph to identify connected components
#         print(f"Step 1: Building sparse graph (k={k_neighbors_initial})...")
#         sparse_graph = self._build_sparse_graph(self.remaining_points, k_neighbors_initial)
        
#         if sparse_graph.number_of_edges() == 0:
#             print("  No edges in sparse graph. Cannot extract tree.")
#             return None
        
#         # Step 2: Find largest connected component
#         print(f"Step 2: Finding connected components...")
#         components = list(nx.connected_components(sparse_graph))
#         print(f"  Found {len(components)} components")
        
#         if len(components) == 0:
#             return None
        
#         # Get largest component
#         largest_component = max(components, key=len)
#         print(f"  Largest component: {len(largest_component)} nodes")
        
#         if len(largest_component) < min_tree_size:
#             print(f"  Component too small (< {min_tree_size}). Skipping.")
#             return None
        
#         # Step 3: Extract points for this component
#         component_indices = sorted(list(largest_component))
#         component_points = self.remaining_points[component_indices]
        
#         print(f"Step 3: Extracting subgraph with {len(component_points)} points...")
        
#         # Step 4: Optimize this tree using standard CCO with higher k
#         print(f"Step 4: Optimizing tree (k={k_neighbors_optimization})...")
#         reconstructor = VascularTreeReconstruction(
#             component_points,
#             gamma=self.gamma,
#             mu=self.mu,
#             Q_perf=self.Q_perf,
#             P_out=self.P_out,
#             P_in=self.P_in
#         )
        
#         try:
#             tree, root, radii, metrics = reconstructor.reconstruct(
#                 k_neighbors=k_neighbors_optimization,
#                 n_candidates=5,
#                 optimize_bifurcations=True
#             )
#         except Exception as e:
#             print(f"  Failed to reconstruct tree: {e}")
#             return None
        
#         # Step 5: Map back to original point indices
#         # component_indices maps from component local indices to remaining_points indices
#         # We need to map to original point cloud indices
        
#         # Find original indices for these remaining points
#         original_indices = self._get_original_indices(component_indices)
        
#         tree_data = {
#             'tree': tree,
#             'root': root,  # Root in local component indexing
#             'radii': radii,
#             'metrics': metrics,
#             'points': component_points,
#             'point_indices': original_indices,  # Indices in original point cloud
#             'reconstructor': reconstructor
#         }
        
#         return tree_data
    
#     def _build_sparse_graph(self, points, k_neighbors):
#         """
#         Build a sparse k-NN graph (lower k helps separate disconnected trees)
#         """
#         from scipy.spatial import cKDTree
        
#         n_points = len(points)
#         tree = cKDTree(points)
        
#         # Create graph
#         G = nx.Graph()
        
#         # Add all nodes
#         for i in range(n_points):
#             G.add_node(i)
        
#         # Add k-NN edges
#         for i in range(n_points):
#             dists, indices = tree.query(points[i], k=min(k_neighbors+1, n_points))
#             for j, idx in enumerate(indices[1:]):  # Skip self
#                 if dists[j+1] < np.inf:
#                     G.add_edge(i, idx, weight=dists[j+1])
        
#         return G
    
#     def _get_original_indices(self, component_indices):
#         """
#         Map component indices (in remaining_points) back to original point cloud indices
#         """
#         # Build reverse mapping: remaining_points → original_points
#         original_indices = []
        
#         for comp_idx in component_indices:
#             remaining_point = self.remaining_points[comp_idx]
            
#             # Find this point in original cloud
#             # Use exact match (or nearest neighbor if points have been modified)
#             distances = np.linalg.norm(self.original_points - remaining_point, axis=1)
#             orig_idx = np.argmin(distances)
            
#             # Verify it's a close match
#             if distances[orig_idx] < 0.01:  # Should be exact or very close
#                 original_indices.append(orig_idx)
#             else:
#                 print(f"Warning: Could not find exact match for point {comp_idx}")
#                 original_indices.append(orig_idx)  # Use closest anyway
        
#         return original_indices
    
#     def _remove_tree_points(self, tree_data):
#         """
#         Remove points belonging to extracted tree from remaining points
#         """
#         # Get indices of points to remove (in remaining_points indexing)
#         points_to_remove = tree_data['points']
        
#         # Find which indices in remaining_points to keep
#         keep_mask = np.ones(len(self.remaining_points), dtype=bool)
        
#         for i, point in enumerate(self.remaining_points):
#             # Check if this point is in the extracted tree
#             distances = np.linalg.norm(points_to_remove - point, axis=1)
#             if np.min(distances) < 0.01:  # Point is in tree
#                 keep_mask[i] = False
        
#         # Update remaining points
#         self.remaining_points = self.remaining_points[keep_mask]
    
#     def visualize_all_trees(self, show_remaining=True):
#         """
#         Visualize all extracted trees in a single 3D plot
#         """
#         fig = plt.figure(figsize=(15, 12))
#         ax = fig.add_subplot(111, projection='3d')
        
#         # Color palette for different trees
#         colors = plt.cm.tab10(np.linspace(0, 1, len(self.trees)))
        
#         for tree_idx, tree_data in enumerate(self.trees):
#             tree = tree_data['tree']
#             points = tree_data['points']
#             radii = tree_data['radii']
#             root = tree_data['root']
#             color = colors[tree_idx]
            
#             # Draw edges
#             for u, v in tree.edges():
#                 pos_u = points[u]
#                 pos_v = points[v]
#                 radius = radii[v]
#                 linewidth = max(0.5, min(5, radius * 10))
                
#                 ax.plot([pos_u[0], pos_v[0]], 
#                        [pos_u[1], pos_v[1]], 
#                        [pos_u[2], pos_v[2]], 
#                        color=color, linewidth=linewidth, alpha=0.7)
            
#             # Highlight root
#             root_pos = points[root]
#             ax.scatter(*root_pos, c=[color], s=200, marker='o', 
#                       edgecolors='black', linewidths=2, 
#                       label=f'Tree {tree_idx+1} root')
            
#             # Show terminals
#             terminals = [n for n in tree.nodes() if tree.out_degree(n) == 0]
#             terminal_pos = points[terminals]
#             if len(terminal_pos) > 0:
#                 ax.scatter(terminal_pos[:, 0], terminal_pos[:, 1], terminal_pos[:, 2],
#                           c=[color], s=30, marker='^', alpha=0.5)
        
#         # Show remaining unassigned points
#         if show_remaining and len(self.remaining_points) > 0:
#             ax.scatter(self.remaining_points[:, 0], 
#                       self.remaining_points[:, 1], 
#                       self.remaining_points[:, 2],
#                       c='gray', s=5, alpha=0.3, label='Unassigned points')
        
#         ax.set_xlabel('X')
#         ax.set_ylabel('Y')
#         ax.set_zlabel('Z')
#         ax.legend()
#         ax.set_title(f'Multi-Tree Reconstruction ({len(self.trees)} trees)')
        
#         plt.tight_layout()
#         return fig, ax
    
#     def export_all_trees(self, base_filename):
#         """
#         Export all trees to separate JSON files for viewer
        
#         Parameters:
#         -----------
#         base_filename : str
#             Base name for output files (e.g., "hepatic_vein")
#             Will create: hepatic_vein_tree1.json, hepatic_vein_tree2.json, etc.
#         """
#         import json
        
#         for tree_idx, tree_data in enumerate(self.trees):
#             filename = f"{base_filename}_tree{tree_idx+1}.json"
            
#             tree = tree_data['tree']
#             points = tree_data['points']
#             radii = tree_data['radii']
            
#             branches = []
            
#             for parent, child in tree.edges():
#                 start_pos = points[parent].tolist()
#                 end_pos = points[child].tolist()
#                 radius = float(radii[child])
#                 Q = float(radius ** 3 * 100)
                
#                 branch = {
#                     "start": start_pos,
#                     "end": end_pos,
#                     "radius": radius,
#                     "Q": Q
#                 }
#                 branches.append(branch)
            
#             with open(filename, 'w') as f:
#                 json.dump(branches, f, indent=2)
            
#             print(f"Tree {tree_idx+1} exported to {filename} ({len(branches)} branches)")
    
#     def get_tree_statistics(self):
#         """
#         Print summary statistics for all trees
#         """
#         print(f"\n{'='*60}")
#         print(f"MULTI-TREE STATISTICS")
#         print(f"{'='*60}\n")
        
#         total_points = sum(len(t['point_indices']) for t in self.trees)
#         total_volume = sum(t['metrics']['total_volume'] for t in self.trees)
        
#         print(f"Total trees: {len(self.trees)}")
#         print(f"Total points assigned: {total_points} / {len(self.original_points)}")
#         print(f"Total volume: {total_volume:.2f} mm³")
#         print(f"Unassigned points: {len(self.remaining_points)}\n")
        
#         for i, tree_data in enumerate(self.trees):
#             print(f"Tree {i+1}:")
#             print(f"  Points: {len(tree_data['point_indices'])}")
#             print(f"  Root: {tree_data['points'][tree_data['root']]}")
            
#             tree = tree_data['tree']
#             terminals = [n for n in tree.nodes() if tree.out_degree(n) == 0]
#             bifurcations = [n for n in tree.nodes() 
#                            if tree.out_degree(n) == 2 and tree.in_degree(n) == 1]
            
#             print(f"  Terminals: {len(terminals)}")
#             print(f"  Bifurcations: {len(bifurcations)}")
#             print(f"  Volume: {tree_data['metrics']['total_volume']:.2f} mm³")
#             print(f"  Murray error: {tree_data['metrics']['murray_error_mean']:.4f}")
            
#             radii_values = list(tree_data['radii'].values())
#             print(f"  Radius range: [{min(radii_values):.3f}, {max(radii_values):.3f}] mm")
#             print()

# %%
# Example usages

def example_multi_tree_usage():
    """
    Example: Extract multiple hepatic vein trees from skeleton
    """
    # Load your skeleton points
    skeleton_points = np.load('hepatic_skeleton.npy')  # Shape: (N, 3)
    
    # Or generate synthetic data for testing
    # skeleton_points = generate_multi_tree_test_data()
    
    # Initialize multi-tree reconstructor
    reconstructor = MultiTreeReconstruction(
        skeleton_points,
        n_trees=3,  # Expect 3 major hepatic veins
        gamma=3.0,
        mu=3.6e-3,
        Q_perf=0.125,
        P_out=60,
        P_in=100
    )
    
    # Extract multiple trees
    trees = reconstructor.reconstruct_multiple_trees(
        k_neighbors_initial=5,      # Low k for separation
        k_neighbors_optimization=10, # Higher k for optimization
        min_tree_size=50,            # Minimum points per tree
        max_iterations=10            # Safety limit
    )
    
    # Print statistics
    reconstructor.get_tree_statistics()
    
    # Visualize all trees together
    fig, ax = reconstructor.visualize_all_trees(show_remaining=True)
    plt.show()
    
    # Export for viewer
    reconstructor.export_all_trees('hepatic_veins')
    
    return reconstructor, trees


def generate_multi_tree_test_data():
    """
    Generate synthetic skeleton with 3 separate trees for testing
    """
    np.random.seed(42)
    all_points = []
    
    # Tree 1: Right hepatic vein
    trunk1 = []
    for i in range(30):
        trunk1.append([20 + i*0.5, 10 + i*0.3, i])
    for _ in range(50):
        base = trunk1[np.random.randint(0, len(trunk1))]
        offset = np.random.randn(3) * 3
        trunk1.append(base + offset)
    all_points.extend(trunk1)
    
    # Tree 2: Middle hepatic vein
    trunk2 = []
    for i in range(30):
        trunk2.append([0 + i*0.3, 15 + i*0.4, i])
    for _ in range(50):
        base = trunk2[np.random.randint(0, len(trunk2))]
        offset = np.random.randn(3) * 3
        trunk2.append(base + offset)
    all_points.extend(trunk2)
    
    # Tree 3: Left hepatic vein
    trunk3 = []
    for i in range(30):
        trunk3.append([-20 + i*0.4, 20 + i*0.2, i])
    for _ in range(50):
        base = trunk3[np.random.randint(0, len(trunk3))]
        offset = np.random.randn(3) * 3
        trunk3.append(base + offset)
    all_points.extend(trunk3)
    
    return np.array(all_points)


# if __name__ == "__main__":
    # Run example
    # reconstructor, trees = example_multi_tree_usage()

# %%
# thinning = load_thinning(nib.load("../skeleton-viewer/data/hepaticvessel_001.nii.gz")[0])
thinning = json.load(open("../zenodo_skeletons/Task08_HepaticVessel/skeletons/hepaticvessel_001_LNC.json", 'r'))

reconstructor = MultiTreeReconstruction(
    thinning,
    n_trees=3,  # Expect 3 major hepatic veins
    gamma=3.0,
    mu=3.6e-3,
    Q_perf=0.125,
    P_out=60,
    P_in=100
)

# Extract multiple trees
trees = reconstructor.reconstruct_multiple_trees(
    k_neighbors_initial=3,      # Low k for separation
    k_neighbors_optimization=10, # Higher k for optimization
    min_tree_size=10,            # Minimum points per tree
    max_iterations=10,            # Safety limit
    methods=["highest_z", "lowest_z", "lowest_z"]  # Different root selection for each tree
)

# Print statistics
reconstructor.get_tree_statistics()

# Visualize all trees together
fig, ax = reconstructor.visualize_all_trees(show_remaining=True)
plt.show()

# Export for viewer
reconstructor.export_all_trees('test-data/1hepatic_veins')
# Out:
# Starting multi-tree reconstruction from 1432 points
# Target: 3 trees
#
# ============================================================
# ITERATION 1: 1432 points remaining
# ============================================================
#
# Using root candidate method: highest_z
# Step 1: Building sparse graph (k=3)...
# Step 2: Finding connected components...
#   Found 15 components
#   Largest component: 973 nodes
# Step 3: Extracting subgraph with 973 points...
# Step 4: Optimizing tree (k=10)...
# Building graph from skeleton points...
# Graph built: 973 nodes, 972 edges
# Found 5 candidates from superior endpoints
# Found 5 root candidates
#
# Evaluating 5 root candidates...
#
# Candidate 1/5: node 960
#   Terminals: 71, Total nodes: 973
#   Optimizing 70 bifurcations...
#   Metrics: volume=28.35, murray_error=0.0000, radius_violations=0
#
# Candidate 2/5: node 956
#   Terminals: 71, Total nodes: 973
#   Optimizing 70 bifurcations...
#   Metrics: volume=27.01, murray_error=0.0000, radius_violations=0
#
# Candidate 3/5: node 958
#   Terminals: 71, Total nodes: 973
#   Optimizing 70 bifurcations...
#   Metrics: volume=10.92, murray_error=0.0000, radius_violations=0
#
# Candidate 4/5: node 378
#   Terminals: 71, Total nodes: 973
#   Optimizing 70 bifurcations...
#   Metrics: volume=28.42, murray_error=0.0000, radius_violations=0
#
# Candidate 5/5: node 20
#   Terminals: 71, Total nodes: 973
#   Optimizing 70 bifurcations...
#   Metrics: volume=9.66, murray_error=0.0000, radius_violations=0
#
# === Best tree (root=20) ===
#   total_volume: 9.657913921941883
#   radius_violations: 0
#   murray_error_mean: 3.753016957984137e-16
#   murray_error_max: 6.91283923128171e-16
#   mean_bifurcation_angle: 108.88943136605785
#   min_bifurcation_angle: 19.286325413321705
#   root_z_score: 0.9999999999973683
#
# ✓ Tree 1 extracted: 973 points
#   Root at: [273 274  38]
#   Terminals: 71
#   Total volume: 9.66 mm³
#   Remaining points: 459
#
# ============================================================
# ITERATION 2: 459 points remaining
# ============================================================
#
# Using root candidate method: lowest_z
# Step 1: Building sparse graph (k=3)...
# Step 2: Finding connected components...
#   Found 14 components
#   Largest component: 346 nodes
# Step 3: Extracting subgraph with 346 points...
# Step 4: Optimizing tree (k=10)...
# Building graph from skeleton points...
# Graph built: 346 nodes, 345 edges
# Found 5 candidates from inferior endpoints
# Found 5 root candidates
#
# Evaluating 5 root candidates...
#
# Candidate 1/5: node 308
#   Terminals: 37, Total nodes: 346
#   Optimizing 34 bifurcations...
#   Metrics: volume=2.35, murray_error=0.0000, radius_violations=0
#
# Candidate 2/5: node 309
#   Terminals: 37, Total nodes: 346
#   Optimizing 34 bifurcations...
#   Metrics: volume=2.35, murray_error=0.0000, radius_violations=0
#
# Candidate 3/5: node 286
#   Terminals: 37, Total nodes: 346
#   Optimizing 34 bifurcations...
#   Metrics: volume=33.51, murray_error=0.0000, radius_violations=0
#
# Candidate 4/5: node 311
#   Terminals: 37, Total nodes: 346
#   Optimizing 34 bifurcations...
#   Metrics: volume=29.30, murray_error=0.0000, radius_violations=0
#
# Candidate 5/5: node 312
#   Terminals: 37, Total nodes: 346
#   Optimizing 34 bifurcations...
#   Metrics: volume=11.66, murray_error=0.0000, radius_violations=0
#
# === Best tree (root=312) ===
#   total_volume: 11.658192254974164
#   radius_violations: 0
#   murray_error_mean: 1.739088058878928e-16
#   murray_error_max: 4.019812393402387e-16
#   mean_bifurcation_angle: 98.3112154922972
#   min_bifurcation_angle: 18.434948825639793
#   root_z_score: 0.2702702702695398
#
# ✓ Tree 2 extracted: 346 points
#   Root at: [374 249  10]
#   Terminals: 37
#   Total volume: 11.66 mm³
#   Remaining points: 113
#
# ============================================================
# ITERATION 3: 113 points remaining
# ============================================================
#
# Using root candidate method: lowest_z
# Step 1: Building sparse graph (k=3)...
# Step 2: Finding connected components...
#   Found 13 components
#   Largest component: 24 nodes
# Step 3: Extracting subgraph with 24 points...
# Step 4: Optimizing tree (k=10)...
# Building graph from skeleton points...
# Graph built: 24 nodes, 23 edges
# Found 2 candidates from inferior endpoints
# Found 2 root candidates
#
# Evaluating 2 root candidates...
#
# Candidate 1/2: node 21
#   Terminals: 1, Total nodes: 24
#   Optimizing 0 bifurcations...
#   Metrics: volume=2.06, murray_error=0.0000, radius_violations=0
#
# Candidate 2/2: node 23
#   Terminals: 1, Total nodes: 24
#   Optimizing 0 bifurcations...
#   Metrics: volume=2.09, murray_error=0.0000, radius_violations=0
#
# === Best tree (root=23) ===
#   total_volume: 2.0936357315895666
#   radius_violations: 0
#   murray_error_mean: 0
#   murray_error_max: 0
#   mean_bifurcation_angle: 0
#   min_bifurcation_angle: 0
#   root_z_score: 0.9999999999973683
#
# ✓ Tree 3 extracted: 24 points
#   Root at: [284 271  38]
#   Terminals: 1
#   Total volume: 2.09 mm³
#   Remaining points: 89
#
# Extracted target number of trees (3). Stopping.
#
# ============================================================
# FINAL RESULT: 3 trees extracted
# ============================================================
# Tree 1: 973 points, volume=9.66 mm³
# Tree 2: 346 points, volume=11.66 mm³
# Tree 3: 24 points, volume=2.09 mm³
#
# Warning: 89 points not assigned to any tree
#
# ============================================================
# MULTI-TREE STATISTICS
# ============================================================
#
# Total trees: 3
# Total points assigned: 1343 / 1432
# Total volume: 23.41 mm³
# Unassigned points: 89
#
# Tree 1:
#   Points: 973
#   Root: [273 274  38]
#   Terminals: 71
#   Bifurcations: 70
#   Volume: 9.66 mm³
#   Murray error: 0.0000
#   Radius range: [0.000, 0.422] mm
#
# Tree 2:
#   Points: 346
#   Root: [374 249  10]
#   Terminals: 37
#   Bifurcations: 34
#   Volume: 11.66 mm³
#   Murray error: 0.0000
#   Radius range: [0.006, 0.390] mm
#
# Tree 3:
#   Points: 24
#   Root: [284 271  38]
#   Terminals: 1
#   Bifurcations: 0
#   Volume: 2.09 mm³
#   Murray error: 0.0000
#   Radius range: [0.150, 0.150] mm
# Tree 1 exported to test-data/1hepatic_veins_tree1.json (972 branches)
# Tree 2 exported to test-data/1hepatic_veins_tree2.json (345 branches)
# Tree 3 exported to test-data/1hepatic_veins_tree3.json (23 branches)

# %% [markdown]
# ## Perform skeletonization from the raw mask
#
# All the cells above loaded a *precomputed* skeleton (`hepaticvessel_001_LNC.json`).
# This instead runs actual skeletonization — `reconstruction.load_thinning`, which wraps
# `skimage.morphology.skeletonize` (medial-axis thinning) — directly on the raw
# segmentation mask `../skeleton-viewer/data/hepaticvessel_001.nii.gz`, producing our own
# skeleton point cloud from scratch.
#
# Task08_HepaticVessel masks use labels `0 = background, 1 = vessel, 2 = tumor`; we keep
# only the vessel label before thinning. The cell prints the unique label values found so
# you can double check that assumption against this particular file.

# %%
import nibabel as nib
from reconstruction import load_thinning, save_skeleton

mask_path = "../skeleton-viewer/data/hepaticvessel_001.nii.gz"
img = nib.load(mask_path)
mask_data = img.get_fdata()

print("Volume shape:", mask_data.shape)
print("Unique label values:", np.unique(mask_data))

vessel_mask = (mask_data == 1)
print(f"Vessel voxels: {int(vessel_mask.sum())}")

skeleton_points = load_thinning(vessel_mask)
print(f"Skeleton points after thinning: {len(skeleton_points)}")

save_skeleton(skeleton_points, "data/hepaticvessel_001_skeletonized.json")
# Out:
# Volume shape: (512, 512, 49)
# Unique label values: [0. 1. 2.]
# Vessel voxels: 8887
# Skeleton points after thinning: 1284
# Skeleton saved to data/hepaticvessel_001_skeletonized.json

# %%
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(skeleton_points[:, 0], skeleton_points[:, 1], skeleton_points[:, 2],
           s=2, alpha=0.5, c=skeleton_points[:, 2], cmap='viridis')
ax.set_title(f"Skeletonized points from {mask_path} ({len(skeleton_points)} voxels)")
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Reconstruct trees from the freshly skeletonized points and export for the viewer
#
# Same corrected-optimizer monkey-patch pattern as before (reverted right after the
# run), applied to `skeleton_points` from actual skeletonization rather than the
# precomputed `_LNC.json`. Distinct variable names (`reconstructor_skel`,
# `trees_skel`) so nothing from earlier cells gets overwritten.

# %%
import reconstruction
from reconstruction import MultiTreeReconstruction

_original_optimize_bifurcation = reconstruction.VascularTreeReconstruction.optimize_bifurcation
reconstruction.VascularTreeReconstruction.optimize_bifurcation = (
    reconstruction.VascularTreeReconstruction.optimize_bifurcation_corrected
)

try:
    reconstructor_skel = MultiTreeReconstruction(
        skeleton_points,
        n_trees=3,
        gamma=3.0,
        mu=3.6e-3,
        Q_perf=0.125,
        P_out=60,
        P_in=100
    )

    trees_skel = reconstructor_skel.reconstruct_multiple_trees(
        k_neighbors_initial=3,
        k_neighbors_optimization=10,
        min_tree_size=10,
        max_iterations=10,
        methods=["highest_z", "lowest_z", "lowest_z"]
    )
finally:
    reconstruction.VascularTreeReconstruction.optimize_bifurcation = _original_optimize_bifurcation

reconstructor_skel.get_tree_statistics()

fig, ax = reconstructor_skel.visualize_all_trees(show_remaining=True)
plt.show()
# Out:
# Starting multi-tree reconstruction from 1284 points
# Target: 3 trees
#
# ============================================================
# ITERATION 1: 1284 points remaining
# ============================================================
#
# Using root candidate method: highest_z
# Step 1: Building sparse graph (k=3)...
# Step 2: Finding connected components...
#   Found 17 components
#   Largest component: 875 nodes
# Step 3: Extracting subgraph with 875 points...
# Step 4: Optimizing tree (k=10)...
# Building graph from skeleton points...
# Graph built: 875 nodes, 874 edges
# Found 5 candidates from superior endpoints
# Found 5 root candidates
#
# Evaluating 5 root candidates...
#
# Candidate 1/5: node 529
#   Terminals: 49, Total nodes: 875
#   Optimizing 48 bifurcations...
#   Metrics: volume=6.29, murray_error=0.0000, radius_violations=0
#
# Candidate 2/5: node 454
#   Terminals: 49, Total nodes: 875
#   Optimizing 48 bifurcations...
#   Metrics: volume=10.59, murray_error=0.0000, radius_violations=0
#
# Candidate 3/5: node 711
#   Terminals: 49, Total nodes: 875
#   Optimizing 48 bifurcations...
#   Metrics: volume=33.91, murray_error=0.0000, radius_violations=0
#
# Candidate 4/5: node 20
#   Terminals: 49, Total nodes: 875
#   Optimizing 48 bifurcations...
#   Metrics: volume=59.51, murray_error=0.0000, radius_violations=0
#
# Candidate 5/5: node 388
#   Terminals: 49, Total nodes: 875
#   Optimizing 48 bifurcations...
#   Metrics: volume=22.36, murray_error=0.0000, radius_violations=0
#
# === Best tree (root=388) ===
#   total_volume: 22.359882357329482
#   radius_violations: 0
#   murray_error_mean: 3.220172962399645e-16
#   murray_error_max: 5.570302921315032e-16
#   mean_bifurcation_angle: 115.60652678561034
#   min_bifurcation_angle: 29.205932248144954
#   root_z_score: 0.9999999999973683
#
# ✓ Tree 1 extracted: 875 points
#   Root at: [324 271  38]
#   Terminals: 49
#   Total volume: 22.36 mm³
#   Remaining points: 409
#
# ============================================================
# ITERATION 2: 409 points remaining
# ============================================================
#
# Using root candidate method: lowest_z
# Step 1: Building sparse graph (k=3)...
# Step 2: Finding connected components...
#   Found 16 components
#   Largest component: 297 nodes
# Step 3: Extracting subgraph with 297 points...
# Step 4: Optimizing tree (k=10)...
# Building graph from skeleton points...
# Graph built: 297 nodes, 296 edges
# Found 5 candidates from inferior endpoints
# Found 5 root candidates
#
# Evaluating 5 root candidates...
#
# Candidate 1/5: node 292
#   Terminals: 16, Total nodes: 297
#   Optimizing 15 bifurcations...
#   Metrics: volume=16.66, murray_error=0.0000, radius_violations=0
#
# Candidate 2/5: node 239
#   Terminals: 16, Total nodes: 297
#   Optimizing 15 bifurcations...
#   Metrics: volume=21.86, murray_error=0.0000, radius_violations=0
#
# Candidate 3/5: node 291
#   Terminals: 16, Total nodes: 297
#   Optimizing 15 bifurcations...
#   Metrics: volume=19.82, murray_error=0.0000, radius_violations=0
#
# Candidate 4/5: node 281
#   Terminals: 16, Total nodes: 297
#   Optimizing 15 bifurcations...
#   Metrics: volume=16.57, murray_error=0.0000, radius_violations=0
#
# Candidate 5/5: node 240
#   Terminals: 16, Total nodes: 297
#   Optimizing 15 bifurcations...
#   Metrics: volume=8.83, murray_error=0.0000, radius_violations=0
#
# === Best tree (root=240) ===
#   total_volume: 8.834852857646556
#   radius_violations: 0
#   murray_error_mean: 1.8496451417993331e-16
#   murray_error_max: 2.707050319070583e-16
#   mean_bifurcation_angle: 101.28008496806683
#   min_bifurcation_angle: 43.08872313648113
#   root_z_score: 0.38888888888780865
#
# ✓ Tree 2 extracted: 297 points
#   Root at: [363 273  14]
#   Terminals: 16
#   Total volume: 8.83 mm³
#   Remaining points: 112
#
# ============================================================
# ITERATION 3: 112 points remaining
# ============================================================
#
# Using root candidate method: lowest_z
# Step 1: Building sparse graph (k=3)...
# Step 2: Finding connected components...
#   Found 15 components
#   Largest component: 22 nodes
# Step 3: Extracting subgraph with 22 points...
# Step 4: Optimizing tree (k=10)...
# Building graph from skeleton points...
# Graph built: 22 nodes, 21 edges
# Found 2 candidates from inferior endpoints
# Found 2 root candidates
#
# Evaluating 2 root candidates...
#
# Candidate 1/2: node 21
#   Terminals: 1, Total nodes: 22
#   Optimizing 0 bifurcations...
#   Metrics: volume=1.77, murray_error=0.0000, radius_violations=0
#
# Candidate 2/2: node 0
#   Terminals: 1, Total nodes: 22
#   Optimizing 0 bifurcations...
#   Metrics: volume=1.77, murray_error=0.0000, radius_violations=0
#
# === Best tree (root=0) ===
#   total_volume: 1.7724610252130701
#   radius_violations: 0
#   murray_error_mean: 0
#   murray_error_max: 0
#   mean_bifurcation_angle: 0
#   min_bifurcation_angle: 0
#   root_z_score: 0.9999999999972973
#
# ✓ Tree 3 extracted: 22 points
#   Root at: [287 273  37]
#   Terminals: 1
#   Total volume: 1.77 mm³
#   Remaining points: 90
#
# Extracted target number of trees (3). Stopping.
#
# ============================================================
# FINAL RESULT: 3 trees extracted
# ============================================================
# Tree 1: 875 points, volume=22.36 mm³
# Tree 2: 297 points, volume=8.83 mm³
# Tree 3: 22 points, volume=1.77 mm³
#
# Warning: 90 points not assigned to any tree
#
# ============================================================
# MULTI-TREE STATISTICS
# ============================================================
#
# Total trees: 3
# Total points assigned: 1194 / 1284
# Total volume: 32.97 mm³
# Unassigned points: 90
#
# Tree 1:
#   Points: 875
#   Root: [324 271  38]
#   Terminals: 49
#   Bifurcations: 48
#   Volume: 22.36 mm³
#   Murray error: 0.0000
#   Radius range: [0.000, 0.401] mm
#
# Tree 2:
#   Points: 297
#   Root: [363 273  14]
#   Terminals: 16
#   Bifurcations: 15
#   Volume: 8.83 mm³
#   Murray error: 0.0000
#   Radius range: [0.013, 0.310] mm
#
# Tree 3:
#   Points: 22
#   Root: [287 273  37]
#   Terminals: 1
#   Bifurcations: 0
#   Volume: 1.77 mm³
#   Murray error: 0.0000
#   Radius range: [0.148, 0.148] mm

# %%
# Export for viewer — written under a distinct basename so it doesn't clobber the
# earlier test-data/1hepatic_veins*.json exports.
reconstructor_skel.export_all_trees('test-data/hepaticvessel_001_skeletonized')
# Out:
# Tree 1 exported to test-data/hepaticvessel_001_skeletonized_tree1.json (874 branches)
# Tree 2 exported to test-data/hepaticvessel_001_skeletonized_tree2.json (296 branches)
# Tree 3 exported to test-data/hepaticvessel_001_skeletonized_tree3.json (21 branches)

# %% [markdown]
# ## Test both improvements together and export for the viewer
#
# Two fixes have been added to `VascularTreeReconstruction` so far (both additive — the
# original methods are untouched):
# - `optimize_bifurcation_corrected` — fixes `optimize_bifurcation`'s objective, which
#   was algebraically ~0 everywhere and so never actually optimized anything (see
#   `lab_diary.md` §4.1)
# - `compute_radii_iterative` — fixes `compute_radii`'s terminal resistance, which was
#   hardcoded to a placeholder `R=1.0` that a comment says should be updated but never
#   is; this iteratively solves the resistance/radius fixed point using each terminal's
#   actual segment length instead
#
# This cell monkey-patches **both** onto the class for this run only (reverted in
# `finally`, same non-invasive pattern as before) and reruns the freshly skeletonized
# points (`skeleton_points`) through the full `MultiTreeReconstruction` pipeline, so we
# can see their combined effect on real data. Distinct variable names
# (`reconstructor_improved`, `trees_improved`) so `reconstructor_skel`/`trees_skel`
# (bifurcation-fix-only, from the previous cell) stay intact for comparison.

# %%
import reconstruction
from reconstruction import MultiTreeReconstruction

_original_optimize_bifurcation = reconstruction.VascularTreeReconstruction.optimize_bifurcation
_original_compute_radii = reconstruction.VascularTreeReconstruction.compute_radii

reconstruction.VascularTreeReconstruction.optimize_bifurcation = (
    reconstruction.VascularTreeReconstruction.optimize_bifurcation_corrected
)
reconstruction.VascularTreeReconstruction.compute_radii = (
    reconstruction.VascularTreeReconstruction.compute_radii_iterative
)

try:
    reconstructor_improved = MultiTreeReconstruction(
        skeleton_points,
        n_trees=3,
        gamma=3.0,
        mu=3.6e-3,
        Q_perf=0.125,
        P_out=60,
        P_in=100
    )

    trees_improved = reconstructor_improved.reconstruct_multiple_trees(
        k_neighbors_initial=3,
        k_neighbors_optimization=10,
        min_tree_size=10,
        max_iterations=10,
        methods=["highest_z", "lowest_z", "lowest_z"]
    )
finally:
    # Always restore both originals, even if the run raises, so later cells
    # see the unpatched class again.
    reconstruction.VascularTreeReconstruction.optimize_bifurcation = _original_optimize_bifurcation
    reconstruction.VascularTreeReconstruction.compute_radii = _original_compute_radii

reconstructor_improved.get_tree_statistics()

fig, ax = reconstructor_improved.visualize_all_trees(show_remaining=True)
plt.show()
# Out:
# Starting multi-tree reconstruction from 1284 points
# Target: 3 trees
#
# ============================================================
# ITERATION 1: 1284 points remaining
# ============================================================
#
# Using root candidate method: highest_z
# Step 1: Building sparse graph (k=3)...
# Step 2: Finding connected components...
#   Found 17 components
#   Largest component: 875 nodes
# Step 3: Extracting subgraph with 875 points...
# Step 4: Optimizing tree (k=10)...
# Building graph from skeleton points...
# Graph built: 875 nodes, 874 edges
# Found 5 candidates from superior endpoints
# Found 5 root candidates
#
# Evaluating 5 root candidates...
#
# Candidate 1/5: node 529
#   Terminals: 49, Total nodes: 875
#   Optimizing 48 bifurcations...
#   Metrics: volume=4.31, murray_error=0.0000, radius_violations=0
#
# Candidate 2/5: node 454
#   Terminals: 49, Total nodes: 875
#   Optimizing 48 bifurcations...
#   Metrics: volume=4.75, murray_error=0.0000, radius_violations=0
#
# Candidate 3/5: node 711
#   Terminals: 49, Total nodes: 875
#   Optimizing 48 bifurcations...
#   Metrics: volume=30.22, murray_error=0.0000, radius_violations=0
#
# Candidate 4/5: node 20
#   Terminals: 49, Total nodes: 875
#   Optimizing 48 bifurcations...
#   Metrics: volume=43.02, murray_error=0.0000, radius_violations=0
#
# Candidate 5/5: node 388
#   Terminals: 49, Total nodes: 875
#   Optimizing 48 bifurcations...
#   Metrics: volume=14.62, murray_error=0.0000, radius_violations=0
#
# === Best tree (root=388) ===
#   total_volume: 14.61882229015438
#   radius_violations: 0
#   murray_error_mean: 1.3484652014317349e-15
#   murray_error_max: 1.6281568835323556e-15
#   mean_bifurcation_angle: 116.11350205552738
#   min_bifurcation_angle: 27.520687610532363
#   root_z_score: 0.9999999999973683
#
# ✓ Tree 1 extracted: 875 points
#   Root at: [324 271  38]
#   Terminals: 49
#   Total volume: 14.62 mm³
#   Remaining points: 409
#
# ============================================================
# ITERATION 2: 409 points remaining
# ============================================================
#
# Using root candidate method: lowest_z
# Step 1: Building sparse graph (k=3)...
# Step 2: Finding connected components...
#   Found 16 components
#   Largest component: 297 nodes
# Step 3: Extracting subgraph with 297 points...
# Step 4: Optimizing tree (k=10)...
# Building graph from skeleton points...
# Graph built: 297 nodes, 296 edges
# Found 5 candidates from inferior endpoints
# Found 5 root candidates
#
# Evaluating 5 root candidates...
#
# Candidate 1/5: node 292
#   Terminals: 16, Total nodes: 297
#   Optimizing 15 bifurcations...
#   Metrics: volume=3.69, murray_error=0.0000, radius_violations=0
#
# Candidate 2/5: node 239
#   Terminals: 16, Total nodes: 297
#   Optimizing 15 bifurcations...
#   Metrics: volume=14.06, murray_error=0.0000, radius_violations=0
#
# Candidate 3/5: node 291
#   Terminals: 16, Total nodes: 297
#   Optimizing 15 bifurcations...
#   Metrics: volume=23.44, murray_error=0.0000, radius_violations=0
#
# Candidate 4/5: node 281
#   Terminals: 16, Total nodes: 297
#   Optimizing 15 bifurcations...
#   Metrics: volume=6.06, murray_error=0.0000, radius_violations=0
#
# Candidate 5/5: node 240
#   Terminals: 16, Total nodes: 297
#   Optimizing 15 bifurcations...
#   Metrics: volume=4.35, murray_error=0.0000, radius_violations=0
#
# === Best tree (root=240) ===
#   total_volume: 4.3531433301666285
#   radius_violations: 0
#   murray_error_mean: 9.652805742759212e-16
#   murray_error_max: 1.3380244043376805e-15
#   mean_bifurcation_angle: 100.13918944463936
#   min_bifurcation_angle: 43.08872313648113
#   root_z_score: 0.38888888888780865
#
# ✓ Tree 2 extracted: 297 points
#   Root at: [363 273  14]
#   Terminals: 16
#   Total volume: 4.35 mm³
#   Remaining points: 112
#
# ============================================================
# ITERATION 3: 112 points remaining
# ============================================================
#
# Using root candidate method: lowest_z
# Step 1: Building sparse graph (k=3)...
# Step 2: Finding connected components...
#   Found 15 components
#   Largest component: 22 nodes
# Step 3: Extracting subgraph with 22 points...
# Step 4: Optimizing tree (k=10)...
# Building graph from skeleton points...
# Graph built: 22 nodes, 21 edges
# Found 2 candidates from inferior endpoints
# Found 2 root candidates
#
# Evaluating 2 root candidates...
#
# Candidate 1/2: node 21
#   Terminals: 1, Total nodes: 22
#   Optimizing 0 bifurcations...
#   Metrics: volume=2.15, murray_error=0.0000, radius_violations=0
#
# Candidate 2/2: node 0
#   Terminals: 1, Total nodes: 22
#   Optimizing 0 bifurcations...
#   Metrics: volume=2.15, murray_error=0.0000, radius_violations=0
#
# === Best tree (root=0) ===
#   total_volume: 2.149881563205927
#   radius_violations: 0
#   murray_error_mean: 0
#   murray_error_max: 0
#   mean_bifurcation_angle: 0
#   min_bifurcation_angle: 0
#   root_z_score: 0.9999999999972973
#
# ✓ Tree 3 extracted: 22 points
#   Root at: [287 273  37]
#   Terminals: 1
#   Total volume: 2.15 mm³
#   Remaining points: 90
#
# Extracted target number of trees (3). Stopping.
#
# ============================================================
# FINAL RESULT: 3 trees extracted
# ============================================================
# Tree 1: 875 points, volume=14.62 mm³
# Tree 2: 297 points, volume=4.35 mm³
# Tree 3: 22 points, volume=2.15 mm³
#
# Warning: 90 points not assigned to any tree
#
# ============================================================
# MULTI-TREE STATISTICS
# ============================================================
#
# Total trees: 3
# Total points assigned: 1194 / 1284
# Total volume: 21.12 mm³
# Unassigned points: 90
#
# Tree 1:
#   Points: 875
#   Root: [324 271  38]
#   Terminals: 49
#   Bifurcations: 48
#   Volume: 14.62 mm³
#   Murray error: 0.0000
#   Radius range: [0.000, 0.371] mm
#
# Tree 2:
#   Points: 297
#   Root: [363 273  14]
#   Terminals: 16
#   Bifurcations: 15
#   Volume: 4.35 mm³
#   Murray error: 0.0000
#   Radius range: [0.000, 0.260] mm
#
# Tree 3:
#   Points: 22
#   Root: [287 273  37]
#   Terminals: 1
#   Bifurcations: 0
#   Volume: 2.15 mm³
#   Murray error: 0.0000
#   Radius range: [0.163, 0.163] mm

# %%
# Compare against the bifurcation-fix-only run (reconstructor_skel/trees_skel).
# Note: the two runs may pick different root candidates per tree, since the radius
# fix changes total_volume, which feeds into reconstruct()'s candidate-scoring
# formula — so "Tree 1" in each run isn't guaranteed to be the exact same vessel.
print(f"{'Tree':<6}{'skel-only volume':<20}{'improved volume':<20}{'radius range (skel-only)':<28}{'radius range (improved)'}")
for i in range(min(len(trees_skel), len(trees_improved))):
    v_skel = trees_skel[i]['metrics']['total_volume']
    v_imp = trees_improved[i]['metrics']['total_volume']
    r_skel = list(trees_skel[i]['radii'].values())
    r_imp = list(trees_improved[i]['radii'].values())
    print(f"{i+1:<6}{v_skel:<20.4f}{v_imp:<20.4f}"
          f"[{min(r_skel):.4f}, {max(r_skel):.4f}]{'':<10}[{min(r_imp):.4f}, {max(r_imp):.4f}]")
# Out:
# Tree  skel-only volume    improved volume     radius range (skel-only)    radius range (improved)
# 1     22.3599             14.6188             [0.0001, 0.4010]          [0.0000, 0.3705]
# 2     8.8349              4.3531              [0.0128, 0.3105]          [0.0000, 0.2604]
# 3     1.7725              2.1499              [0.1482, 0.1482]          [0.1632, 0.1632]

# %% [markdown]
# ### Export for the viewer — what's being saved
#
# `reconstructor_improved.export_all_trees('test-data/hepaticvessel_001_improved')`
# writes one file per extracted tree:
#
# - `test-data/hepaticvessel_001_improved_tree1.json`
# - `test-data/hepaticvessel_001_improved_tree2.json`
# - `test-data/hepaticvessel_001_improved_tree3.json`
#
# (fewer files if fewer than 3 trees were extracted). Each file is a JSON **array of
# branch objects**, one per edge in that tree — same schema as the existing
# `1hepatic_veins_tree*.json` / `hepaticvessel_001_skeletonized_tree*.json` exports, so
# it's a drop-in for whatever already loads those in the viewer:
#
# ```json
# [
#   {
#     "start": [x, y, z],   // parent-node voxel coordinates
#     "end":   [x, y, z],   // child-node voxel coordinates
#     "radius": 0.1234,     // estimated vessel radius at the child node (mm)
#     "Q": 1.86              // relative flow proxy = radius**3 * 100
#   },
#   ...
# ]
# ```
#
# Coordinates are in the same voxel-index space as `skeleton_points` (i.e. indices into
# the `hepaticvessel_001.nii.gz` mask volume, not physical mm — no affine/spacing
# transform is applied here). This basename (`_improved`) is distinct from the earlier
# `_skeletonized` export, so both are left on disk and can be loaded side by side in the
# viewer to compare the bifurcation-fix-only result against bifurcation-fix +
# terminal-resistance-fix combined.

# %%
# Export for viewer — written under the "_improved" basename documented above.
reconstructor_improved.export_all_trees('test-data/hepaticvessel_001_improved')
# Out:
# Tree 1 exported to test-data/hepaticvessel_001_improved_tree1.json (874 branches)
# Tree 2 exported to test-data/hepaticvessel_001_improved_tree2.json (296 branches)
# Tree 3 exported to test-data/hepaticvessel_001_improved_tree3.json (21 branches)
